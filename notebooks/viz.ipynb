# %%
import geopandas as gpd
from urllib.request import urlopen
import json
import plotly.graph_objects as go

# %%
dt = gpd.read_file('../carto/h3_aggregated_8.geojson')
grid_geojson = json.loads(dt.to_json())
# Out:
#           h3_res_8   RetailArea  NumBldgs  \
# 0  882a10085bfffff     0.000000         0
# 1  882a100881fffff  1264.331034       326
# 2  882a100883fffff   895.141372      1040
# 3  882a100887fffff     4.411765       106
# 4  882a100889fffff   998.530957       570
#
#                                             geometry
# 0  POLYGON ((-73.94913 40.85585, -73.95552 40.854...
# 1  POLYGON ((-73.97278 40.80229, -73.97917 40.801...
# 2  POLYGON ((-73.97033 40.79441, -73.97672 40.793...
# 3  POLYGON ((-73.98114 40.79677, -73.98752 40.795...
# 4  POLYGON ((-73.96443 40.80780, -73.97081 40.806...

# %%
fig = go.Figure(go.Choroplethmapbox(geojson=grid_geojson, locations=df.index, z=dt.RetailArea,
                                    colorscale="Viridis", zmin=0, zmax=3000,
                                    marker_opacity=0.5, marker_line_width=0))
fig.update_layout(mapbox_style="carto-positron",
                  mapbox_zoom=10,
                  mapbox_center = {"lat": 40.7731607, "lon": -73.9752436})
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
# Out:
# <div>
#
#
#             <div id="7eec48fd-fa29-407c-bd49-d3eef9969970" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7eec48fd-fa29-407c-bd49-d3eef9969970")) {
#                     Plotly.newPlot(
#                         '7eec48fd-fa29-407c-bd49-d3eef9969970',
# ...
